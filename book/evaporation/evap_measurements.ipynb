# %% [markdown]
# # Measuring evaporation
#
# There are various methods to measure evaporation. They can be classified into two categories: methods that are based on the water balance or those that make use of micro-meteorological techniques. Depending on the spatial and temporal scale a method can be more or less suitable. In {numref}`fig:space_time` an overview is given. In general, you can say that the water balance methods work well at either the larger catchment scale or at the smaller spatial scales (m$^2$ to hectares). While the micro-meteorological methods nicely fill the gap between the hectare to km$^2$ scale. In the temporal domain, the micro-meteorological methods perform better at time scales less than a day, while the water balance methods can expand to the yearly scale.
#
# ```{figure} ../images/EVA_measurements_spacetime.png
# ---
# height: 300px
# name: fig:space_time
# ---
# Space-Time. (Own work)
# ```

# %% [markdown]
# ## Water balance techniques

# %% [markdown]
# ### Catchment water balance
# Via the water balance we can estimate the total evaporation of a catchment:
#
# $$
# E_a=P-Q-\frac{\textrm{d}S}{\textrm{d}t}
# $$ (evap_catchment)
#
# Precipitation ($P$) and river discharge ($Q$) measurements are frequently available, especially at large time scales (monthly, yearly). On the other hand, data on storage changes is more difficult to obtain. These storage changes can include:
# - Surface water: changed water levels, readable on level gauge;
# - Groundwater: changed groundwater levels, readable in monitoring wells. The increase in groundwater storage is equal to the increase in the groundwater level multiplied by the storage coefficient;
# - Soil moisture: increase in soil moisture content, determined by sampling or with a neutron probe.
# Hence information on all these components is required, which is often not the case. Therefore the catchment water balance approach is often only used at the yearly time scale because then the storage change can be neglected ($\textrm{d}S/(\textrm{1 year}) \approx 0$). The water balance then simplifies into $E=P-Q$. It is important to realize that the error that arises with this calculation method is a summation of errors in the measured variables.
#
# ### Lake water balance
# Also for lakes the water balance method can be applied if the inflow ($Q_{in}$), outflow ($Q_{out}$), and water level ($h$) are measured:
#
# $$
# E_o=Q_{in} + P-Q_{out}-\frac{\textrm{d}h}{\textrm{d}t}
# $$ (lake_evap)
#
# Although the method can give useful information, its weakness lies in the uncertainties caused by leakage losses that are difficult to estimate. Hence additional measurements are always needed for good lake evaporation estimates, for example, the class-A pan.

# %% [markdown]
# ### Pan evaporation
#
# The most straightforward method to measure open water evaporation directly is with a pan ({numref}`fig:classaevaporation`). The pan is filled with water and every time interval (e.g., daily) the water level is measured. The drop in the water level divided by the time interval gives the rate of open water evaporation. Of course, the water level difference should be compensated for rainfall. Therefore, next to the pan, a rain gauge should be installed.
#
# Various types of pans are in use, such as the sunken pan, floating pan and surface pan. The use of the surface pan is most widely spread, despite its shortcomings. The most common is the U.S. Weather Bureau Class A-Pan, with a diameter of 4ft and depth of 10 inches. The water level is maintained 2-3 inches below the rim ({numref}`fig:classaevaporation`).
#
# ```{figure} ../images/EVA_measurements_classaevapan.png
# ---
# height: 300px
# name: fig:classaevaporation
# ---
# Class A evaporation pan - photo from {cite:p}`instropicsEVA`.
# ```
#
#
# Class A-pans are also used to estimate the potential evaporation over land mainly for irrigation purposes. Then the pan is installed in the field and it is assumed that $E_o \approx E_p$.
#
# Although the Class A-pan is a direct method, one should be careful with assuming that the pan evaporation is an estimate for the open water evaporation. Often the pan evaporation is higher than the open water evaporation due to the warming of the sides by the sun. The shallow pan reacts much faster to temperature changes than deep water. To reduce this effect the pan can be installed on floats in a lake or one can make use of correction factors (see e.g., {cite:t}`grismer-2002` for an overview).
#
# To correct this, empirical *pan coefficients* have been entered:
#
# $$
# E_o=k_{pan} \cdot E_{pan}
# \quad \text{[L/T]}
# $$ (pancoefficient)
#
# Coefficients are mainly derived for the American class-A pan. The values of the pan coefficients can vary widely for different circumstances. However, the average monthly evaporation values determined with the evaporation pan, give a maximum error of about 10. Data about evaporation in pans are always valuable for comparing the evaporation at different places and times.

# %% [markdown]
# ### Lysimeters
#
# One of the oldest and most straightforward ways to measure evaporation is with lysimeters. Lysimeters make use of the mass balance, whereby the known in- and outgoing fluxes and the storage are measured. Rainfall, percolation and soil moisture should often be measured to determine the evaporation (mass balance). The soil moisture can be measured with soil moisture probes but in the case of so-called weighing lysimeters ({numref}`fig:lysimeter`) the water storage can be determined by the weight changes of the lysimeter. Often load cells are used to weigh the lysimeter.
#
# Lysimeters can measure different types of evaporation, depending on the material inside the lysimeter. Forest floor interception can be measured with a lysimeter by filling it with forest floor material {cite:p}`Gerrits2007`. And total evaporation can be determined by filling the lysimeter with vegetation and a soil layer. Open water evaporation can be estimated by filling the lysimeter with water (the lysimeter is hydrologically isolated so the leakage loss $ε$ = 0). So a pan is also a lysimeter.
#
# The advantage of lysimeters is that they are conceptually simple, accurate, and have a fast time response {cite:p}`Gash2007`. Disadvantages are that the edges of the lysimeter can disturb the measurements (altering the wind flow paths, roots, heat source, etc.) and that the soil and vegetation sample will be disturbed {cite:p}`Pruitt1960`. One should also take care that the soil moisture inside the lysimeter is similar to the surroundings. With pumps, this can be accomplished. Furthermore, lysimeters often have a small spatial sample and especially large lysimeters are expensive to construct. Due to these high costs large lysimeters are currently not often used anymore, although they provide accurate (actual) evaporation results.
#
# ```{figure} ../images/EVA_measurements_lysimeter.png
# ---
# height: 300px
# name: fig:lysimeter
# ---
# Lysimeter - photo from {cite:p}`instropicsEVA`.
# ```
#
# Lysimeters are applied:
# - To determine the evaporation term $E$ in the water balance for a specific area;
# - To determine the influence of evaporation on the depth of the groundwater level, the soil condition, or the crop;
# - To determine the drainage, the replenishment of the groundwater or useful precipitation;
# - To determine condensation and dew (only possible due to weighing);
# - To study the chemical composition of the drained water in connection with the uptake and deposition of substances in the soil.
#
# One of the largest lysimeters worldwide are the Davis lysimeters of the University of California {cite:p}`Pruitt1960` which are still operational, and the lysimeters in Castricum (The Netherlands). Although the lysimeters in Castricum are not operational anymore, in 2011 they digitalized all the data from the four 25x25x2.5 meter lysimeters filled with bare soil, dune scrubs, deciduous, and pine. This data is freely available and can be used for research. Currently, three new large lysimeters (30 x 12 m) are built by the University of Arizona to investigate the effect of climate change on vegetation. The lysimeters are constructed in a greenhouse facility where they can control the environment.

# %% [markdown]
# <!--### Interception measurements
#
# The earth's surface is wet after a raining event. Water is stored on the leaves (of trees, shrubs and soil overgrowth), on the paved surfaces (roads, roofs, etc.), in the top layer of the soil, on fallen leaves, etc. A large part of this water (interception) will not be discharged, but will evaporate within a few hours/days after the raining event. This is called interception evaporation ($I$).
#
# In order to determine the amount of water that is retained by trees *canopy interception* and evaporates, a water balance is used (see{numref}`fig:schematisatie`). Three values are measured: the amount of precipitation, the amount of water under the trees *throughfall* and the amount of water which flows via the trunk *stemflow*. The difference between the amount of precipitation and the sum of the stemflow and throughfall is the interception of the tree.
#
# ```{figure} ../images/schematisatieprocesseninterceptie.jpg
# ---
# height: 300px
# name: fig:schematisatie
# ---
# Schematisation of the processes with regard to interception
# ```
#
# The amount of water that is stored in the top layer of the soil *forest floor interception* can be measured with a top layer interception meter (see {numref}`fig:toplayerinterceptie`). This interception meter (developed by University of Technology Delft) consists of two aluminum tubs which are installed, one above the ground and one in the ground. The upper tub is filled with the top layer of the ground and is permeable due to the bottom of geotextile. The lower tub is impermeable and contains a valve to drain off the excess water. The weight of the two tubs ($S_u$ and $S_l$) is accurately measured with strain gauges. The evaporation of the top layer ($E_i$) of the soil is determined by neglecting the evaporation from the bottom tank, measuring the precipitation, weighing $S_u$ and $S_l$ and registering the amount of water that is drained.
# ```{figure} ../images/toplayerinterceptiemeter.jpg
# ---
# height: 300px
# name: fig:toplayerinterceptie
# ---
# Top layer interception meter
# ```
#  -->

# %% [markdown]
# ## Micro-meteorological methods
# Micrometeorological methods refer to methods in which evaporation is measured as vertical vapor flux through the air. The evaporation can take place from open water, soil or vegetation. The measurements are made in the turbulent air close to the ground. So the measured vapor flux is a good approximation of surface evaporation.
#
# <!--There are two types of micrometeorological measurements:
# - The method by which average gradients are measured. This method assumes that the transport of water vapor and evaporation heat can be described by vertical one-dimensional diffusion comparisons. Hereby it is assumed that characteristics of the turbulent air layer are of influence, rather than those of the evaporation surface.
# - Aerodynamic methods relate the aerodynamic resistance (relationship between evaporation and the difference in vapor pressure at various heights) to the wind speed profile.
# -->

# %% [markdown]
# ### Eddy Covariance System
# The eddy covariance (or eddy correlation) method measures vertical turbulent fluxes within the atmospheric boundary layer to estimate evaporation. The method requires turbulence in the air so that a horizontal wind flow consists of numerous rotating eddies (turbulent vortices of various sizes) with each eddy having horizontal and vertical components (see {numref}`fig:eddies`). The eddies transport an entity of interest. This can be heat, water vapor or gases {cite:p}`burba-2010`.
#
#
# :::{figure} ../images/EVA_measurements_eddies.png
# ---
# height: 300px
# name: fig:eddies
# ---
# Principle of eddy covariance (or eddy correlation) method – photo by {cite:p}`burba-2010`.
# :::
#
# The basic idea behind the method is to count how many molecules/parcels (of the entity) are moving up and down over time, and how fast they travel. This is the definition of a flux: concentration times velocity. So for example for the entity water, at time 1 three molecules of water vapor are moving upwards and at time 2 two molecules are moving downwards. The net flux is then that one water vapor molecule is moving upwards. An eddy covariance system can do this for water to estimate the latent heat flux, for heat to estimate the sensible heat flux, and/or for carbon to estimate the CO$_2$ flux.
#
# <!--In a mathematical way we can say that the vertical flux, $F$, can be represented as the mean product of the vertical velocity ($w$) and the concentration of the entity of interest ($c$). When we define $s$ as the mixing ratio ($\rho_{c}/\rho_{a}$) of substance $c$ in air, the vertical flux becomes:
# \begin{equation}
# 	F=\overline{\rho_{a} \cdot w \cdot s}
# \label{eq:ec1}
# \end{equation}
# And after decomposition:
# \begin{equation}
# 	F=\overline{(\bar \rho_{a}+\rho'_{a})(\bar w + w')(\bar s + s')}
# \label{eq:ec2}
# \end{equation}
# whereby the bars indicate the overall mean (e.g., over 30 minutes) and the accents indicate instantaneous deviations  from the mean for every time unit (e.g., every 0.05-0.1 seconds). \\
#
# When we assume no density fluctuations and that the vertical flow is negligible for horizontal homogeneous terrain  Equation \ref{eq:ec2} can be rewritten into (see \citet{Burba2010} for details):
# \begin{equation}
# 	F=\bar \rho_{a} \overline{ w' \cdot s'}
# \label{eq:ec3}
# \end{equation}
#
# As mentioned before, the entity of interest, $s$ can be heat, water vapor or gases. Depending on which entity is measured the Eddy Covariance method can give an estimation for the sensible heat flux $H$, the latent heat flux $\rho_{w} \lambda E$, or the carbon dioxide flux $F_{c}$, respectively:
# \begin{eqnarray}
# 	H&=&\rho_{a} c_{p} \overline{ w' \cdot T'}\\
# 	\rho_{w} \lambda E&=&\lambda \frac{M_{w}/M_{a}}{P}\rho_{a}\overline{w' \cdot  e'_{a}}=\lambda \rho_{a} \overline{w' \cdot q'}\\
# 	F_{c}&=&\overline{w' \cdot \rho'_{c}}
# \label{eq:ec4}
# \end{eqnarray}
# with $c_{p}$ the specific heat of air [J/kg/K], $w$ the wind speed [m/s], $T$ temperature [K], $M_{w}$ mass of water [kg], $M_{a}$ mass of air [kg], $P$ air pressure [kPa], and $e_{a}$ actual vapor pressure [kPa], and $q$ the specific humidity [-].\\
# -->
#
# An Eddy Covariance (EC) system ({numref}`fig:EC`) is always equipped with a 3D anemometer to measure the wind speed. Depending on the setup the EC system is also equipped with:
# - InfraRed gas analyzer to measure
#     - water vapor (for the latent heat flux), and/or
#     - CO$_{2}$ concentration (for the carbon flux); and
# - thermocouple to measure the temperature (for the sensible heat flux).
#
# The analyzer and the thermocouple should be installed close or at the height of the anemometer for accurate results. The gas analyzer uses the spectral properties of water vapor and CO$_{2}$ in the infrared region to measure the concentration. To avoid rainfall accumulating on the IR transmitter, the gas analyzer is often installed on a small inclination. The entire installation is installed on a tower (flux tower). The height of the tower is determined by the so-called flux footprint or fetch ({numref}`fig:footprint`). The footprint is the area that the sensors 'see' and should contain the area of interest. If the tower is too high the sensors 'see' outside the area of interest, or 'see' flows that are unaffected by the surface. On the other hand, if the tower is too low small eddies may not be registered {cite:p}`burba-2010`. The footprint can be calculated {cite:p}`schuepp-1990` and is mainly dependent on the measuring height, the surface roughness and the atmospheric thermal stability.
#
#
# ```{figure} ../images/EVA_measurements_eddiesinstros.png
# ---
# height: 300px
# name: fig:EC
# ---
# Eddy Covariance instrumentation with sonic anemometer (upper left) and InfraRed gas analyzer (lower right) to measure water vapor and/or CO$_{2}$ concentrations - photo from {cite:p}`eddy_instro`.
# ```
#
#
# :::{figure} ../images/EVA_measurements_footprint.png
# ---
# height: 200px
# name: fig:footprint
# ---
# Flux footprint. The darker the red color the more contribution that is coming from the surface area a certain distance away for the instrument – data from {cite:p}`burba-2010`.
# :::
#
# Although EC systems are the golden standard to measure the surface energy balance fluxes (e.g., FLUXNET), in practice they are notorious for their large data gaps.

# %% [markdown]
# ### Bowen Ratio Energy Balance
# Another way to determine evaporation is by using the energy balance and the Bowen ratio {cite:p}`bowen-1926`. The Bowen ratio gives the ratio between the sensible heat flux and the latent heat flux. The Bowen ratio can be determined with temperatures and vapor pressures at different heights ($z$):
#
# If combined with the energy balance, this can be rewritten into:
#
# $$
# E= \frac{R_{n}-G}{\rho \lambda(1+\beta)}
# $$ (evap)
#
# $$
# \beta=\frac{H}{\rho\lambda E}=\gamma\frac{T_{z2}-T_{z1}}{e_{a,z2}-e_{a,z1}}
# $$ (bowen)
#
# To determine the evaporation in this way, it is thus necessary to measure the temperature and actual vapor pressure at least 2 heights, plus the net radiation and ground heat flux. Although this seems rather simple, the method is highly sensitive for measuring errors in the gradients. To overcome this, increasing the number of observations of the height is essential. This could for example be achieved by measuring the temperature and vapor pressure gradients by optic cables (Distributed Temperature Sensing) {cite:p}`schilperoort-2018`.
#
# <!--Three measurements will give a more precise result. z1 should be 30 cm above the vegetation, $z_{2}$ 2 meters above $z_{1}$ and $z_{3}$ 2-4 meters above $z_{2}$.
#
# \subsubsection{Example bowen ratio}
# The following data are averaged over one hour on a certain day:
#
# \begin{tabular}{|l|l|l|}
# \hline
# 	&	$T$ ($^{\circ}$C)	&	$e_{a}$ (kPa) \\
# 	\hline
# $z_{1}$ (0.5 m)	& 20	&	0.88 \\
# $z_{2}$ (2.5 m)	& 18	&	0.82 \\
# $z_{3}$ (6.5 m)	& 16	&	0.75 \\
# \hline
# \end{tabular}
#
# The average net radiation during this hour is $R_{N}$=200 W/m$^{2}$
#
#
# The Bowen ratio can now be determined by plotting the vapour pressure to the temperature (Figure \ref{fig:bowen}).
#
# \begin{figure}[ht]
# \centering
# \includegraphics[width=0.5\textwidth]{Evaporation/img/bowen_example.png}
# \caption{Values for vapour pressure and temperature}
# \label{fig:bowen}
# \end{figure}
#
#
# From the trend line in Figure \ref{fig:bowen} the Bowen ratio can be derived:
#
# \begin{equation}
# \beta=\gamma \frac{\Delta T}{\Delta e_{a}}=0.066*\frac{4}{0.11}=2.4
# \label{eq:bowen_ex}
# \end{equation}
#
#
# From the Bowen ratio the evaporation can be determined:
#
# \begin{equation}
# E=\frac{R_{N}}{\rho\lambda(1+\beta)}=\frac{200 \cdot 3600}{1000 \cdot 2.45\cdot 10^{6}*(1+2.4)}=8.6\cdot 10^{-5}\textrm{m/hour}=0.086 \textrm{mm/hour}
# \label{eq:evap_ex}
# \end{equation}
#
# When this evaporation would be constant during 12 hours a day, this would lead to evaporation of 1.03 mm/day.
#
# Note: In this case it seems a bit unnecessary to plot a trend line because the line fits perfect to all the data point. Of course in the field this won't be the case, so it will be necessary to make a plot with a trend line.-->

# %%
# Note that the code cells below is used for the website only.

# %% [markdown]
# ```{exercise-start} Bowen ratio
# :label: example_evap_3
# ```
# For two heights you have temperature and humidity data:
# - Height = 5m : T = 12 degrees, h = 50%
# - Height = 2m : T = 12.5 degrees, h = 51%
#
# The net radiation equals $150W/m^2$ and the ground heat flux can be assumed to be 10%
# of the net radiation.
#
# a) Calculate the bowen ratio.
#
# b) What would be the latent heat, sensible heat, and evaporation?
#
# ```{exercise-end}
# ```
#
# :::{dropdown} Answer&nbsp;{ref}`example_evap_3`a
#
# First convert relative humidity into e<sub>a</sub> for the 2 heights:
#
# $$
# e_{a,5} = h_5 * e_s(T_5=12) = 0.5 * e_s(T=12) = 0.5 * 0.61 * \exp \bigg(\frac{19.9*12}{273+12}\bigg) = 0.71
# $$
#
# $$
# e_{a,2} = h_2 * e_s(T_2=12.5) = 0.51 * e_s(T=12.5) = 0.51 * 0.61 * \exp \bigg(\frac{19.9*12.5}{273+12.5}\bigg) = 0.74
# $$
#
# Thus from {eq}`bowen` the bowen ratio is:
#
# $$
# \beta = \gamma\frac{T_{5}-T_{2}}{e_{a,5}-e_{a,2}} =  0.066 * \frac{12-12.5}{0.71-0.74} = 1.1
# $$
#
# :::
#
# :::{dropdown} Answer&nbsp;{ref}`example_evap_3`b
#
# $$
# E\rho \lambda = \frac{R_{n}-G}{(1+\beta)} = \frac{150-0.1*150}{(1+1.1)} = 64.29 \ \ [W/m^2]
# $$
#
# Given the formula:
#
# $$
# R_n = E\rho\lambda + H + G
# $$
#
# With G = 0.1 *R<sub>n</sub> and solving for H the answer is given by:
#
# $$
# H = R_n - E\rho\lambda - 0.1*R_n = 150 - 64.29 - 0.1*150 = 70.71 \ \ [W/m^2]
# $$
#
# And thus for evaporation for the given latent heat:
#
# $$
# E = 64.29 / \rho\lambda = 64.29 / (1000  * 2.45*10^6) = 2.62*10^{-8} \ \ [m/s] = 2.26 \ \ [mm/day]
# $$
# :::

# %% [markdown]
# ### Scintillometer
# A scintillometer makes use of the fact that when water evaporates from a surface, temperature and humidity fluctuations in the near-surface atmospheric boundary layer will occur. These fluctuations cause air density variations, which can be observed when a beam of electromagnetic radiation is emitted from a transmitter to a receiver. By analyzing the intensity variations (or scintillations) in the received signal either the sensible or the latent heat flux can be obtained depending on the used wavelength. When the visible and near-infrared waveband is used the air density differences are mainly caused by temperature fluctuations and hence the scintillometer gives the sensible heat flux. These scintillometers are called Large or Extra-Large Aperture Scintillometers (see {numref}`fig:scintillometer`) and have proven to give accurate line average sensible heat flux estimates up to 10 km and are most often used {cite:p}`mcaneney-1995`. Combined with net radiation measurements actual evaporation can be determined when the energy balance is used.
#
# Scintillometers can also directly give the latent heat flux. When the micro-to-millimeter waveband is used, the air density differences are most sensitive to moisture fluctuations. {cite:t}`meijninger-2006` showed that these scintillometers can give reasonable evaporation estimates. However, these Small Aperature Scintillometers (SAS) are more expensive compared to Large Aperature Scintillometers (LAS) and are (thus) less commonly used.
#
#
# ```{figure} ../images/EVA_measurements_scintillometer.png
# ---
# height: 300px
# name: fig:scintillometer
# ---
# Scintillometer – photo from {cite:p}`Scintillometer`.
# ```
